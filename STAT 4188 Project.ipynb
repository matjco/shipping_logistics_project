# %%
import pandas as pd
import numpy as np
import sklearn as sk

# %%
order_list = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - OrderList.csv', sep=',', encoding='ISO-8859-1')
freight_rates = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - FreightRates.csv', sep=',', encoding='ISO-8859-1')
wh_costs = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - WhCosts.csv', sep=',', encoding='ISO-8859-1')
wh_capacities = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - WhCapacities.csv', sep=',', encoding='ISO-8859-1')
products_per_plant = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - ProductsPerPlant.csv', sep=',', encoding='ISO-8859-1')
vmi_customers = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - VmiCustomers.csv', sep=',', encoding='ISO-8859-1')
plant_ports = pd.read_csv(r'C:\Users\mattt\Documents\Spring 2024\STAT 4188\shipping_project\Dataset\Supply chain logisitcs problem - PlantPorts.csv', sep=',', encoding='ISO-8859-1')

# %%
order_list.head()
# Out:
#      Order ID Order Date Origin Port Carrier  TPT Service Level  \
# 0  1447296447  5/26/2013      PORT09   V44_3    1           CRF
# 1  1447158015  5/26/2013      PORT09   V44_3    1           CRF
# 2  1447138899  5/26/2013      PORT09   V44_3    1           CRF
# 3  1447363528  5/26/2013      PORT09   V44_3    1           CRF
# 4  1447363981  5/26/2013      PORT09   V44_3    1           CRF
#
#    Ship ahead day count  Ship Late Day count   Customer  Product ID  \
# 0                     3                    0  V55555_53     1700106
# 1                     3                    0  V55555_53     1700106
# 2                     3                    0  V55555_53     1700106
# 3                     3                    0  V55555_53     1700106
# 4                     3                    0  V55555_53     1700106
#
#   Plant Code Destination Port  Unit quantity  Weight
# 0    PLANT16           PORT09            808   14.30
# 1    PLANT16           PORT09           3188   87.94
# 2    PLANT16           PORT09           2331   61.20
# 3    PLANT16           PORT09            847   16.16
# 4    PLANT16           PORT09           2163   52.34

# %%
Left_join = pd.merge(order_list,  
                      products_per_plant,  
                      on ='Product ID', 
                      how ='left')

# %%
Left_join.head(50)
# Out:
#       Order ID Order Date Origin Port Carrier  TPT Service Level  \
# 0   1447296447  5/26/2013      PORT09   V44_3    1           CRF
# 1   1447158015  5/26/2013      PORT09   V44_3    1           CRF
# 2   1447138899  5/26/2013      PORT09   V44_3    1           CRF
# 3   1447363528  5/26/2013      PORT09   V44_3    1           CRF
# 4   1447363981  5/26/2013      PORT09   V44_3    1           CRF
# 5   1447351441  5/26/2013      PORT09   V44_3    1           CRF
# 6   1447320236  5/26/2013      PORT09   V44_3    1           CRF
# 7   1447158019  5/26/2013      PORT09   V44_3    1           CRF
# 8   1447219341  5/26/2013      PORT09   V44_3    1           CRF
# 9   1447398416  5/26/2013      PORT09   V44_3    1           CRF
# 10  1447381679  5/26/2013      PORT09   V44_3    1           CRF
# 11  1447170785  5/26/2013      PORT09   V44_3    1           CRF
# 12  1447155056  5/26/2013      PORT09   V44_3    1           CRF
# 13  1447257265  5/26/2013      PORT09   V44_3    1           CRF
# 14  1447240989  5/26/2013      PORT09   V44_3    1           CRF
# 15  1447257231  5/26/2013      PORT09   V44_3    1           CRF
# 16  1447260653  5/26/2013      PORT09   V44_3    1           CRF
# 17  1447139375  5/26/2013      PORT09   V44_3    1           CRF
# 18  1447308590  5/26/2013      PORT09   V44_3    1           CRF
# 19  1447191271  5/26/2013      PORT09   V44_3    1           CRF
# 20  1447191284  5/26/2013      PORT09   V44_3    1           CRF
# 21  1447352426  5/26/2013      PORT09   V44_3    1           CRF
# 22  1447211829  5/26/2013      PORT09   V44_3    1           CRF
# 23  1447232833  5/26/2013      PORT09   V44_3    1           CRF
# 24  1447205081  5/26/2013      PORT09   V44_3    1           CRF
# 25  1447365980  5/26/2013      PORT09   V44_3    1           CRF
# 26  1447157118  5/26/2013      PORT09   V44_3    1           CRF
# 27  1447398413  5/26/2013      PORT09   V44_3    1           CRF
# 28  1447377319  5/26/2013      PORT09   V44_3    1           CRF
# 29  1447257239  5/26/2013      PORT09   V44_3    1           CRF
# 30  1447368959  5/26/2013      PORT09   V44_3    1           CRF
# 31  1447308591  5/26/2013      PORT09   V44_3    1           CRF
# 32  1447398479  5/26/2013      PORT09   V44_3    1           CRF
# 33  1447377316  5/26/2013      PORT09   V44_3    1           CRF
# 34  1447365993  5/26/2013      PORT09   V44_3    1           CRF
# 35  1447223051  5/26/2013      PORT09   V44_3    1           CRF
# 36  1447260686  5/26/2013      PORT09   V44_3    1           CRF
# 37  1447299202  5/26/2013      PORT09   V44_3    1           CRF
# 38  1447330061  5/26/2013      PORT09   V44_3    1           CRF
# 39  1447260670  5/26/2013      PORT09   V44_3    1           CRF
# 40  1447157119  5/26/2013      PORT09   V44_3    1           CRF
# 41  1447205082  5/26/2013      PORT09   V44_3    1           CRF
# 42  1447398412  5/26/2013      PORT09   V44_3    1           CRF
# 43  1447257238  5/26/2013      PORT09   V44_3    1           CRF
# 44  1447241003  5/26/2013      PORT09   V44_3    1           CRF
# 45  1447398481  5/26/2013      PORT09   V44_3    1           CRF
# 46  1447398420  5/26/2013      PORT09   V44_3    1           CRF
# 47  1447308592  5/26/2013      PORT09   V44_3    1           CRF
# 48  1447241005  5/26/2013      PORT09   V44_3    1           CRF
# 49  1447191288  5/26/2013      PORT09   V44_3    1           CRF
#
#     Ship ahead day count  Ship Late Day count   Customer  Product ID  \
# 0                      3                    0  V55555_53     1700106
# 1                      3                    0  V55555_53     1700106
# 2                      3                    0  V55555_53     1700106
# 3                      3                    0  V55555_53     1700106
# 4                      3                    0  V55555_53     1700106
# 5                      3                    0  V55555_53     1700106
# 6                      3                    0  V55555_53     1700106
# 7                      3                    0  V55555_53     1700106
# 8                      3                    0  V55555_53     1700106
# 9                      3                    0  V55555_53     1700106
# 10                     3                    0  V55555_53     1700106
# 11                     3                    0  V55555_53     1700106
# 12                     3                    0  V55555_53     1697884
# 13                     3                    0  V55555_53     1697884
# 14                     3                    0  V55555_53     1697884
# 15                     3                    0  V55555_53     1697884
# 16                     3                    0  V55555_53     1697884
# 17                     3                    0  V55555_53     1697884
# 18                     3                    0  V55555_53     1697884
# 19                     3                    0  V55555_53     1697884
# 20                     3                    0  V55555_53     1699336
# 21                     3                    0  V55555_53     1702652
# 22                     3                    0  V55555_53     1699337
# 23                     3                    0  V55555_53     1699337
# 24                     3                    0  V55555_53     1699336
# 25                     3                    0  V55555_53     1702654
# 26                     3                    0  V55555_53     1699336
# 27                     3                    0  V55555_53     1702652
# 28                     3                    0  V55555_53     1702652
# 29                     3                    0  V55555_53     1699337
# 30                     3                    0  V55555_53     1702653
# 31                     3                    0  V55555_53     1699336
# 32                     3                    0  V55555_53     1702652
# 33                     3                    0  V55555_53     1702652
# 34                     3                    0  V55555_53     1702653
# 35                     3                    0  V55555_53     1699336
# 36                     3                    0  V55555_53     1699337
# 37                     3                    0  V55555_53     1699336
# 38                     3                    0  V55555_53     1702652
# 39                     3                    0  V55555_53     1699336
# 40                     3                    0  V55555_53     1699337
# 41                     3                    0  V55555_53     1699336
# 42                     3                    0  V55555_53     1702654
# 43                     3                    0  V55555_53     1699336
# 44                     3                    0  V55555_53     1699336
# 45                     3                    0  V55555_53     1702652
# 46                     3                    0  V55555_53     1702653
# 47                     3                    0  V55555_53     1699337
# 48                     3                    0  V55555_53     1699337
# 49                     3                    0  V55555_53     1699337
#
#    Plant Code_x Destination Port  Unit quantity  Weight Plant Code_y
# 0       PLANT16           PORT09            808   14.30      PLANT16
# 1       PLANT16           PORT09           3188   87.94      PLANT16
# 2       PLANT16           PORT09           2331   61.20      PLANT16
# 3       PLANT16           PORT09            847   16.16      PLANT16
# 4       PLANT16           PORT09           2163   52.34      PLANT16
# 5       PLANT16           PORT09           3332   92.80      PLANT16
# 6       PLANT16           PORT09           1782   46.90      PLANT16
# 7       PLANT16           PORT09            427    2.86      PLANT16
# 8       PLANT16           PORT09           1291   26.60      PLANT16
# 9       PLANT16           PORT09           2294   62.20      PLANT16
# 10      PLANT16           PORT09           2766   75.50      PLANT16
# 11      PLANT16           PORT09            798   14.30      PLANT16
# 12      PLANT16           PORT09            739   73.90      PLANT16
# 13      PLANT16           PORT09            280    7.80      PLANT16
# 14      PLANT16           PORT09            574   59.50      PLANT16
# 15      PLANT16           PORT09            556   52.70      PLANT16
# 16      PLANT16           PORT09            544   58.50      PLANT16
# 17      PLANT16           PORT09           1151  181.70      PLANT16
# 18      PLANT16           PORT09           1404  227.20      PLANT16
# 19      PLANT16           PORT09            662   74.10      PLANT16
# 20      PLANT16           PORT09            836   80.43      PLANT16
# 21      PLANT16           PORT09           2063  265.10      PLANT16
# 22      PLANT16           PORT09           2114  267.10      PLANT16
# 23      PLANT16           PORT09           2108  271.10      PLANT16
# 24      PLANT16           PORT09           1120  112.60      PLANT16
# 25      PLANT16           PORT09            706   61.80      PLANT16
# 26      PLANT16           PORT09            889  107.88      PLANT16
# 27      PLANT16           PORT09           1793  216.57      PLANT16
# 28      PLANT16           PORT09            491   27.81      PLANT16
# 29      PLANT16           PORT09           1044  112.60      PLANT16
# 30      PLANT16           PORT09            447   32.90      PLANT16
# 31      PLANT16           PORT09            328   13.36      PLANT16
# 32      PLANT16           PORT09            973  106.88      PLANT16
# 33      PLANT16           PORT09           1179  129.14      PLANT16
# 34      PLANT16           PORT09            814   74.25      PLANT16
# 35      PLANT16           PORT09           1464  171.22      PLANT16
# 36      PLANT16           PORT09            347    6.18      PLANT16
# 37      PLANT16           PORT09            771   77.25      PLANT16
# 38      PLANT16           PORT09            469   27.90      PLANT16
# 39      PLANT16           PORT09            382   15.45      PLANT16
# 40      PLANT16           PORT09            507   43.17      PLANT16
# 41      PLANT16           PORT09            419   16.45      PLANT16
# 42      PLANT16           PORT09            452   33.90      PLANT16
# 43      PLANT16           PORT09            486   24.72      PLANT16
# 44      PLANT16           PORT09            729   60.80      PLANT16
# 45      PLANT16           PORT09            366   19.54      PLANT16
# 46      PLANT16           PORT09            539   43.26      PLANT16
# 47      PLANT16           PORT09            304    9.27      PLANT16
# 48      PLANT16           PORT09            544   46.35      PLANT16
# 49      PLANT16           PORT09            679   65.80      PLANT16

# %%
#Left_join = Left_join.dropna(axis = 0)

# %%
#Left_join.head()

# %%
join_products_plants = pd.merge(products_per_plant, plant_ports, on = 'Plant Code', how = 'right')

# %%
join_products_plants.head()
# Out:
#   Plant Code  Product ID    Port
# 0    PLANT01   1654431.0  PORT01
# 1    PLANT01   1664406.0  PORT01
# 2    PLANT01   1664416.0  PORT01
# 3    PLANT01   1665542.0  PORT01
# 4    PLANT01   1665863.0  PORT01

# %%
join_all = pd.merge(order_list, join_products_plants, on = 'Plant Code', how = 'right')

# %%
join_all = join_all.dropna(axis = 0)

# %%
join_all.head(10)
# Out:
#          Order ID Order Date Origin Port Carrier  TPT Service Level  \
# 556  1.447307e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 557  1.447307e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 558  1.447393e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 559  1.447307e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 560  1.447190e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 561  1.447190e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 562  1.447190e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 563  1.447406e+09  5/26/2013      PORT04   V44_3  0.0           CRF
# 564  1.447307e+09  5/26/2013      PORT04   V44_3  4.0           CRF
# 565  1.447182e+09  5/26/2013      PORT04   V44_3  4.0           CRF
#
#      Ship ahead day count  Ship Late Day count             Customer  \
# 556                   0.0                  0.0  V555555555555555_29
# 557                   0.0                  0.0  V555555555555555_29
# 558                   0.0                  0.0  V555555555555555_29
# 559                   0.0                  0.0  V555555555555555_29
# 560                   0.0                  0.0  V555555555555555_29
# 561                   0.0                  0.0  V555555555555555_29
# 562                   0.0                  0.0  V555555555555555_29
# 563                   0.0                  0.0  V555555555555555_29
# 564                   0.0                  0.0  V555555555555555_29
# 565                   0.0                  0.0  V555555555555555_29
#
#      Product ID_x Plant Code Destination Port  Unit quantity     Weight  \
# 556     1699333.0    PLANT03           PORT09         1529.0   3.008251
# 557     1699268.0    PLANT03           PORT09         1495.0   2.653360
# 558     1699268.0    PLANT03           PORT09          899.0   1.326680
# 559     1699268.0    PLANT03           PORT09         1437.0   2.653360
# 560     1699584.0    PLANT03           PORT09         1914.0   5.940000
# 561     1699584.0    PLANT03           PORT09         1956.0   5.940000
# 562     1699584.0    PLANT03           PORT09         1964.0   5.940000
# 563     1699584.0    PLANT03           PORT09         1961.0   5.940000
# 564     1699584.0    PLANT03           PORT09         3624.0  11.820000
# 565     1699562.0    PLANT03           PORT09         4802.0   8.892328
#
#      Product ID_y    Port
# 556     1613321.0  PORT04
# 557     1613321.0  PORT04
# 558     1613321.0  PORT04
# 559     1613321.0  PORT04
# 560     1613321.0  PORT04
# 561     1613321.0  PORT04
# 562     1613321.0  PORT04
# 563     1613321.0  PORT04
# 564     1613321.0  PORT04
# 565     1613321.0  PORT04

# %%
order_ports = []
order_id = []

#for i in range (0, join_all.shape[0]):
#    order_id.append(join_all['Order ID'].loc[join_all.index[i]])

# %%
order_id
# Out:
# []

# %%
order_ports.append(order_id)

# %%
order_list_simplified = order_list.drop(['Order Date', 'Origin Port', 'TPT', 'Service Level', 'Ship ahead day count', 'Ship Late Day count', 'Customer', 'Destination Port'], axis = 1)

# %% [markdown]
# Clean the data table 'Freight Rates'

# %%
def rate_remove_symbols(string):
    if isinstance(string, str):
        return string.replace("$", "")

# %%
def convert_to_float(string):
    if isinstance(string, str):
        return float(string)

# %%
freight_rates['rate'] = freight_rates['rate'].apply(rate_remove_symbols)
freight_rates['rate'] = freight_rates['rate'].apply(convert_to_float)

# %%
freight_rates
# Out:
#      Carrier orig_port_cd dest_port_cd  minm_wgh_qty max_wgh_qty svc_cd  \
# 0     V444_6       PORT08       PORT09         250.0      499.99    DTD
# 1     V444_6       PORT08       PORT09          65.0       69.99    DTD
# 2     V444_6       PORT08       PORT09          60.0       64.99    DTD
# 3     V444_6       PORT08       PORT09          50.0       54.99    DTD
# 4     V444_6       PORT08       PORT09          35.0       39.99    DTD
# ...      ...          ...          ...           ...         ...    ...
# 1535  V444_8       PORT03       PORT09           0.0       99.99    DTD
# 1536  V444_8       PORT03       PORT09         500.0     1999.99    DTD
# 1537  V444_8       PORT03       PORT09         250.0      499.99    DTD
# 1538  V444_8       PORT03       PORT09        2000.0    99999.99    DTD
# 1539  V444_8       PORT03       PORT09         100.0      249.99    DTD
#
#      minimum cost  rate mode_dsc  tpt_day_cnt Carrier type
# 0        $ 43.23   0.71   AIR               2  V88888888_0
# 1        $ 43.23   0.75   AIR               2  V88888888_0
# 2        $ 43.23   0.79   AIR               2  V88888888_0
# 3        $ 43.23   0.83   AIR               2  V88888888_0
# 4        $ 43.23   1.06   AIR               2  V88888888_0
# ...           ...   ...      ...          ...          ...
# 1535     $ 29.34   0.41   AIR               0  V88888888_0
# 1536     $ 29.34   0.31   AIR               0  V88888888_0
# 1537     $ 29.34   0.41   AIR               0  V88888888_0
# 1538     $ 29.34   0.31   AIR               0  V88888888_0
# 1539     $ 29.34   0.41   AIR               0  V88888888_0
#
# [1540 rows x 11 columns]

# %%
#freight_rates_simplified = freight_rates.groupby('Carrier').max().reset_index()

# %%
freight_rates_simplified = freight_rates.drop(['dest_port_cd', 'minm_wgh_qty', 'max_wgh_qty', 'svc_cd', 'minimum cost', 'mode_dsc', 'tpt_day_cnt', 'Carrier type'], axis = 1)

# %%
freight_rates_simplified
# Out:
#      Carrier orig_port_cd  rate
# 0     V444_6       PORT08  0.71
# 1     V444_6       PORT08  0.75
# 2     V444_6       PORT08  0.79
# 3     V444_6       PORT08  0.83
# 4     V444_6       PORT08  1.06
# ...      ...          ...   ...
# 1535  V444_8       PORT03  0.41
# 1536  V444_8       PORT03  0.31
# 1537  V444_8       PORT03  0.41
# 1538  V444_8       PORT03  0.31
# 1539  V444_8       PORT03  0.41
#
# [1540 rows x 3 columns]

# %%
#order_list_freight_rates = pd.merge(order_list_simplified, freight_rates, how = 'outer')

# %%
order_list_simplified
# Out:
#         Order ID Carrier  Product ID Plant Code  Unit quantity     Weight
# 0     1447296447   V44_3     1700106    PLANT16            808  14.300000
# 1     1447158015   V44_3     1700106    PLANT16           3188  87.940000
# 2     1447138899   V44_3     1700106    PLANT16           2331  61.200000
# 3     1447363528   V44_3     1700106    PLANT16            847  16.160000
# 4     1447363981   V44_3     1700106    PLANT16           2163  52.340000
# ...          ...     ...         ...        ...            ...        ...
# 9210  1447305023  V444_1     1683388    PLANT03            339   2.354118
# 9211  1447318797  V444_1     1683388    PLANT03            339   2.354118
# 9212  1447322252  V444_1     1683388    PLANT03            245   0.294265
# 9213  1447145319  V444_1     1683430    PLANT03            278   2.480000
# 9214  1447328131  V444_1     1683424    PLANT03            317   1.960000
#
# [9215 rows x 6 columns]

# %%
#every possible freight
order_list_freight_rates = pd.merge(order_list_simplified, freight_rates_simplified, how = 'cross')
order_list_freight_rates = pd.merge(order_list_freight_rates, wh_costs, left_on = 'Plant Code', right_on = 'WH')

# %%
#order_list_freight_rates = order_list_freight_rates.dropna()

# %%
order_list_freight_rates
# Out:
#             Order ID Carrier_x  Product ID Plant Code  Unit quantity  Weight  \
# 0         1447296447     V44_3     1700106    PLANT16            808   14.30
# 1         1447296447     V44_3     1700106    PLANT16            808   14.30
# 2         1447296447     V44_3     1700106    PLANT16            808   14.30
# 3         1447296447     V44_3     1700106    PLANT16            808   14.30
# 4         1447296447     V44_3     1700106    PLANT16            808   14.30
# ...              ...       ...         ...        ...            ...     ...
# 14191095  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191096  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191097  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191098  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191099  1447328131    V444_1     1683424    PLANT03            317    1.96
#
#          Carrier_y orig_port_cd  rate       WH  Cost/unit
# 0           V444_6       PORT08  0.71  PLANT16       1.92
# 1           V444_6       PORT08  0.75  PLANT16       1.92
# 2           V444_6       PORT08  0.79  PLANT16       1.92
# 3           V444_6       PORT08  0.83  PLANT16       1.92
# 4           V444_6       PORT08  1.06  PLANT16       1.92
# ...            ...          ...   ...      ...        ...
# 14191095    V444_8       PORT03  0.41  PLANT03       0.52
# 14191096    V444_8       PORT03  0.31  PLANT03       0.52
# 14191097    V444_8       PORT03  0.41  PLANT03       0.52
# 14191098    V444_8       PORT03  0.31  PLANT03       0.52
# 14191099    V444_8       PORT03  0.41  PLANT03       0.52
#
# [14191100 rows x 11 columns]

# %%
order_list_freight_rates['Total Freight Cost'] = order_list_freight_rates['Unit quantity'] * order_list_freight_rates['rate']
order_list_freight_rates['Total Warehouse Cost'] = order_list_freight_rates['Unit quantity'] * order_list_freight_rates['Cost/unit']
order_list_freight_rates['Total Cost'] = order_list_freight_rates['Total Freight Cost'] + order_list_freight_rates['Total Warehouse Cost']

# %%
order_list_freight_rates
# Out:
#             Order ID Carrier_x  Product ID Plant Code  Unit quantity  Weight  \
# 0         1447296447     V44_3     1700106    PLANT16            808   14.30
# 1         1447296447     V44_3     1700106    PLANT16            808   14.30
# 2         1447296447     V44_3     1700106    PLANT16            808   14.30
# 3         1447296447     V44_3     1700106    PLANT16            808   14.30
# 4         1447296447     V44_3     1700106    PLANT16            808   14.30
# ...              ...       ...         ...        ...            ...     ...
# 14191095  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191096  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191097  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191098  1447328131    V444_1     1683424    PLANT03            317    1.96
# 14191099  1447328131    V444_1     1683424    PLANT03            317    1.96
#
#          Carrier_y orig_port_cd  rate       WH  Cost/unit  Total Freight Cost  \
# 0           V444_6       PORT08  0.71  PLANT16       1.92              573.68
# 1           V444_6       PORT08  0.75  PLANT16       1.92              606.00
# 2           V444_6       PORT08  0.79  PLANT16       1.92              638.32
# 3           V444_6       PORT08  0.83  PLANT16       1.92              670.64
# 4           V444_6       PORT08  1.06  PLANT16       1.92              856.48
# ...            ...          ...   ...      ...        ...                 ...
# 14191095    V444_8       PORT03  0.41  PLANT03       0.52              129.97
# 14191096    V444_8       PORT03  0.31  PLANT03       0.52               98.27
# 14191097    V444_8       PORT03  0.41  PLANT03       0.52              129.97
# 14191098    V444_8       PORT03  0.31  PLANT03       0.52               98.27
# 14191099    V444_8       PORT03  0.41  PLANT03       0.52              129.97
#
#           Total Warehouse Cost  Total Cost
# 0                      1551.36     2125.04
# 1                      1551.36     2157.36
# 2                      1551.36     2189.68
# 3                      1551.36     2222.00
# 4                      1551.36     2407.84
# ...                        ...         ...
# 14191095                164.84      294.81
# 14191096                164.84      263.11
# 14191097                164.84      294.81
# 14191098                164.84      263.11
# 14191099                164.84      294.81
#
# [14191100 rows x 14 columns]

# %%
#from sklearn import tree

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error, mean_absolute_error 
from sklearn import preprocessing

# %%
# plotting a scatterplot 
#sns.scatterplot(x='Order ID', 
#				y='Unit quantity', data=order_list)

# %% [markdown]
# Encoding, assigning each categorical variable to a number

# %%
def encode_carrier(str):
    return float(str[5])

# %%
order_list_freight_rates = order_list_freight_rates.drop('Carrier_x', axis = 1)

# %%
order_list_freight_rates['Carrier_y'] = order_list_freight_rates['Carrier_y'].apply(encode_carrier)

# %%
order_list_freight_rates
# Out:
#             Order ID  Product ID Plant Code  Unit quantity  Weight  Carrier_y  \
# 0         1447296447     1700106    PLANT16            808   14.30        6.0
# 1         1447296447     1700106    PLANT16            808   14.30        6.0
# 2         1447296447     1700106    PLANT16            808   14.30        6.0
# 3         1447296447     1700106    PLANT16            808   14.30        6.0
# 4         1447296447     1700106    PLANT16            808   14.30        6.0
# ...              ...         ...        ...            ...     ...        ...
# 14191095  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191096  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191097  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191098  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191099  1447328131     1683424    PLANT03            317    1.96        8.0
#
#          orig_port_cd  rate       WH  Cost/unit  Total Freight Cost  \
# 0              PORT08  0.71  PLANT16       1.92              573.68
# 1              PORT08  0.75  PLANT16       1.92              606.00
# 2              PORT08  0.79  PLANT16       1.92              638.32
# 3              PORT08  0.83  PLANT16       1.92              670.64
# 4              PORT08  1.06  PLANT16       1.92              856.48
# ...               ...   ...      ...        ...                 ...
# 14191095       PORT03  0.41  PLANT03       0.52              129.97
# 14191096       PORT03  0.31  PLANT03       0.52               98.27
# 14191097       PORT03  0.41  PLANT03       0.52              129.97
# 14191098       PORT03  0.31  PLANT03       0.52               98.27
# 14191099       PORT03  0.41  PLANT03       0.52              129.97
#
#           Total Warehouse Cost  Total Cost
# 0                      1551.36     2125.04
# 1                      1551.36     2157.36
# 2                      1551.36     2189.68
# 3                      1551.36     2222.00
# 4                      1551.36     2407.84
# ...                        ...         ...
# 14191095                164.84      294.81
# 14191096                164.84      263.11
# 14191097                164.84      294.81
# 14191098                164.84      263.11
# 14191099                164.84      294.81
#
# [14191100 rows x 13 columns]

# %% [markdown]
# Regression Model

# %%
# creating feature variables 

#all columns besides the column associated to the dependent variable
#this X is a vector
#X = order_list_freight_rates.drop('Total Cost', axis=1) 
#y = order_list_freight_rates['Total Cost'] 
  
#print(X) 
#print(y) 
  
# creating train and test sets 
#X_train, X_test, y_train, y_test = train_test_split( 
#    X, y, test_size=0.3, random_state=101) 
  
#model = LinearRegression() 
#model.fit(X_train, y_train) 
  
# making predictions 
#predictions = model.predict(X_test)

# %%
#print('Mean squared_error : ', mean_squared_error(y_test, predictions)) 
#print('Mean absolute_error : ', mean_absolute_error(y_test, predictions))

# %% [markdown]
# Selecting the minimum from each

# %%
minimum_cost_freight = order_list_freight_rates.groupby('Order ID')['Total Cost'].idxmin()
minimum_cost_rows = order_list_freight_rates.loc[minimum_cost_freight].reset_index()

#minimum_cost_rows.head(50)

# %%
minimum_cost_freight
# Out:
# Order ID
# 1447125806     6974698
# 1447132026     8426918
# 1447133055     3494298
# 1447133165     6147718
# 1447133210     6269378
#                 ...
# 1447425026    10127078
# 1447425027    10076258
# 1447425028    10090118
# 1447425029    10123998
# 1447425231    12175278
# Name: Total Cost, Length: 9215, dtype: int64

# %%
sns.scatterplot(x='Order ID', 
				y='Carrier_y', data=minimum_cost_rows)
# Out:
# <Axes: xlabel='Order ID', ylabel='Carrier_y'>

# %%
order_list_freight_rates
# Out:
#             Order ID  Product ID Plant Code  Unit quantity  Weight  Carrier_y  \
# 0         1447296447     1700106    PLANT16            808   14.30        6.0
# 1         1447296447     1700106    PLANT16            808   14.30        6.0
# 2         1447296447     1700106    PLANT16            808   14.30        6.0
# 3         1447296447     1700106    PLANT16            808   14.30        6.0
# 4         1447296447     1700106    PLANT16            808   14.30        6.0
# ...              ...         ...        ...            ...     ...        ...
# 14191095  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191096  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191097  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191098  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191099  1447328131     1683424    PLANT03            317    1.96        8.0
#
#          orig_port_cd  rate       WH  Cost/unit  Total Freight Cost  \
# 0              PORT08  0.71  PLANT16       1.92              573.68
# 1              PORT08  0.75  PLANT16       1.92              606.00
# 2              PORT08  0.79  PLANT16       1.92              638.32
# 3              PORT08  0.83  PLANT16       1.92              670.64
# 4              PORT08  1.06  PLANT16       1.92              856.48
# ...               ...   ...      ...        ...                 ...
# 14191095       PORT03  0.41  PLANT03       0.52              129.97
# 14191096       PORT03  0.31  PLANT03       0.52               98.27
# 14191097       PORT03  0.41  PLANT03       0.52              129.97
# 14191098       PORT03  0.31  PLANT03       0.52               98.27
# 14191099       PORT03  0.41  PLANT03       0.52              129.97
#
#           Total Warehouse Cost  Total Cost
# 0                      1551.36     2125.04
# 1                      1551.36     2157.36
# 2                      1551.36     2189.68
# 3                      1551.36     2222.00
# 4                      1551.36     2407.84
# ...                        ...         ...
# 14191095                164.84      294.81
# 14191096                164.84      263.11
# 14191097                164.84      294.81
# 14191098                164.84      263.11
# 14191099                164.84      294.81
#
# [14191100 rows x 13 columns]

# %%
plant_ports
# Out:
#    Plant Code    Port
# 0     PLANT01  PORT01
# 1     PLANT01  PORT02
# 2     PLANT02  PORT03
# 3     PLANT03  PORT04
# 4     PLANT04  PORT05
# 5     PLANT05  PORT06
# 6     PLANT06  PORT06
# 7     PLANT07  PORT01
# 8     PLANT07  PORT02
# 9     PLANT08  PORT04
# 10    PLANT09  PORT04
# 11    PLANT10  PORT01
# 12    PLANT10  PORT02
# 13    PLANT11  PORT04
# 14    PLANT12  PORT04
# 15    PLANT13  PORT04
# 16    PLANT14  PORT07
# 17    PLANT15  PORT08
# 18    PLANT16  PORT09
# 19    PLANT17  PORT10
# 20    PLANT18  PORT11
# 21    PLANT19  PORT04

# %%
#this is a merge approach
#however, an indexing approach may be possible instead
#this approach may not work. this is because more than one port can be associated to each plant

order_list_freight_rates_merge = pd.merge(order_list_freight_rates, plant_ports, on = 'Plant Code', how = 'inner')

# %%
order_list_freight_rates_merge
# Out:
#             Order ID  Product ID Plant Code  Unit quantity  Weight  Carrier_y  \
# 0         1447296447     1700106    PLANT16            808   14.30        6.0
# 1         1447296447     1700106    PLANT16            808   14.30        6.0
# 2         1447296447     1700106    PLANT16            808   14.30        6.0
# 3         1447296447     1700106    PLANT16            808   14.30        6.0
# 4         1447296447     1700106    PLANT16            808   14.30        6.0
# ...              ...         ...        ...            ...     ...        ...
# 14191095  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191096  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191097  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191098  1447328131     1683424    PLANT03            317    1.96        8.0
# 14191099  1447328131     1683424    PLANT03            317    1.96        8.0
#
#          orig_port_cd  rate       WH  Cost/unit  Total Freight Cost  \
# 0              PORT08  0.71  PLANT16       1.92              573.68
# 1              PORT08  0.75  PLANT16       1.92              606.00
# 2              PORT08  0.79  PLANT16       1.92              638.32
# 3              PORT08  0.83  PLANT16       1.92              670.64
# 4              PORT08  1.06  PLANT16       1.92              856.48
# ...               ...   ...      ...        ...                 ...
# 14191095       PORT03  0.41  PLANT03       0.52              129.97
# 14191096       PORT03  0.31  PLANT03       0.52               98.27
# 14191097       PORT03  0.41  PLANT03       0.52              129.97
# 14191098       PORT03  0.31  PLANT03       0.52               98.27
# 14191099       PORT03  0.41  PLANT03       0.52              129.97
#
#           Total Warehouse Cost  Total Cost    Port
# 0                      1551.36     2125.04  PORT09
# 1                      1551.36     2157.36  PORT09
# 2                      1551.36     2189.68  PORT09
# 3                      1551.36     2222.00  PORT09
# 4                      1551.36     2407.84  PORT09
# ...                        ...         ...     ...
# 14191095                164.84      294.81  PORT04
# 14191096                164.84      263.11  PORT04
# 14191097                164.84      294.81  PORT04
# 14191098                164.84      263.11  PORT04
# 14191099                164.84      294.81  PORT04
#
# [14191100 rows x 14 columns]

# %%
def warehouse_port_agreement():
    return order_list_freight_rates_merge['orig_port_cd'] == order_list_freight_rates_merge['Port']

warehouse_port_agreement_bool = warehouse_port_agreement()

# %%
order_list_freight_rates_filter = order_list_freight_rates_merge[warehouse_port_agreement_bool].reset_index()

# %%
order_list_freight_rates_filter
# Out:
#             index    Order ID  Product ID Plant Code  Unit quantity  Weight  \
# 0              38  1447296447     1700106    PLANT16            808   14.30
# 1              39  1447296447     1700106    PLANT16            808   14.30
# 2              40  1447296447     1700106    PLANT16            808   14.30
# 3              41  1447296447     1700106    PLANT16            808   14.30
# 4              42  1447296447     1700106    PLANT16            808   14.30
# ...           ...         ...         ...        ...            ...     ...
# 2092837  14191085  1447328131     1683424    PLANT03            317    1.96
# 2092838  14191086  1447328131     1683424    PLANT03            317    1.96
# 2092839  14191087  1447328131     1683424    PLANT03            317    1.96
# 2092840  14191088  1447328131     1683424    PLANT03            317    1.96
# 2092841  14191089  1447328131     1683424    PLANT03            317    1.96
#
#          Carrier_y orig_port_cd  rate       WH  Cost/unit  Total Freight Cost  \
# 0              8.0       PORT09  0.03  PLANT16       1.92               24.24
# 1              8.0       PORT09  0.03  PLANT16       1.92               24.24
# 2              8.0       PORT09  0.03  PLANT16       1.92               24.24
# 3              8.0       PORT09  0.03  PLANT16       1.92               24.24
# 4              8.0       PORT09  0.03  PLANT16       1.92               24.24
# ...            ...          ...   ...      ...        ...                 ...
# 2092837        8.0       PORT04  0.18  PLANT03       0.52               57.06
# 2092838        8.0       PORT04  0.18  PLANT03       0.52               57.06
# 2092839        8.0       PORT04  0.18  PLANT03       0.52               57.06
# 2092840        8.0       PORT04  0.18  PLANT03       0.52               57.06
# 2092841        8.0       PORT04  0.18  PLANT03       0.52               57.06
#
#          Total Warehouse Cost  Total Cost    Port
# 0                     1551.36      1575.6  PORT09
# 1                     1551.36      1575.6  PORT09
# 2                     1551.36      1575.6  PORT09
# 3                     1551.36      1575.6  PORT09
# 4                     1551.36      1575.6  PORT09
# ...                       ...         ...     ...
# 2092837                164.84       221.9  PORT04
# 2092838                164.84       221.9  PORT04
# 2092839                164.84       221.9  PORT04
# 2092840                164.84       221.9  PORT04
# 2092841                164.84       221.9  PORT04
#
# [2092842 rows x 15 columns]

# %%
minimum_cost_freight = order_list_freight_rates_filter.groupby('Order ID')['Total Cost'].idxmin()
minimum_cost_rows = order_list_freight_rates_filter.loc[minimum_cost_freight].reset_index()

minimum_cost_rows
# Out:
#       level_0     index    Order ID  Product ID Plant Code  Unit quantity  \
# 0     1010391   6974849  1447125806     1660583    PLANT03            262
# 1     1228224   8427069  1447132026     1667927    PLANT03          52742
# 2      488331   3494449  1447133055     1678648    PLANT03            356
# 3      886344   6147869  1447133165     1668492    PLANT03            610
# 4      904593   6269529  1447133210     1683560    PLANT03          71330
# ...       ...       ...         ...         ...        ...            ...
# 9210  1483248  10127229  1447425026     1660580    PLANT03            650
# 9211  1475625  10076409  1447425027     1660580    PLANT03            507
# 9212  1477704  10090269  1447425028     1660580    PLANT03            266
# 9213  1482786  10124149  1447425029     1660580    PLANT03            498
# 9214  1790478  12175429  1447425231     1692949    PLANT03           1629
#
#           Weight  Carrier_y orig_port_cd  rate       WH  Cost/unit  \
# 0       0.594476        0.0       PORT04  0.04  PLANT03       0.52
# 1      30.405274        0.0       PORT04  0.04  PLANT03       0.52
# 2       1.462970        0.0       PORT04  0.04  PLANT03       0.52
# 3       7.676667        0.0       PORT04  0.04  PLANT03       0.52
# 4     670.588931        0.0       PORT04  0.04  PLANT03       0.52
# ...          ...        ...          ...   ...      ...        ...
# 9210   38.920000        0.0       PORT04  0.04  PLANT03       0.52
# 9211   20.243584        0.0       PORT04  0.04  PLANT03       0.52
# 9212    1.069088        0.0       PORT04  0.04  PLANT03       0.52
# 9213   28.120000        0.0       PORT04  0.04  PLANT03       0.52
# 9214    6.487785        0.0       PORT04  0.04  PLANT03       0.52
#
#       Total Freight Cost  Total Warehouse Cost  Total Cost    Port
# 0                  10.48                136.24      146.72  PORT04
# 1                2109.68              27425.84    29535.52  PORT04
# 2                  14.24                185.12      199.36  PORT04
# 3                  24.40                317.20      341.60  PORT04
# 4                2853.20              37091.60    39944.80  PORT04
# ...                  ...                   ...         ...     ...
# 9210               26.00                338.00      364.00  PORT04
# 9211               20.28                263.64      283.92  PORT04
# 9212               10.64                138.32      148.96  PORT04
# 9213               19.92                258.96      278.88  PORT04
# 9214               65.16                847.08      912.24  PORT04
#
# [9215 rows x 16 columns]

# %%
sns.scatterplot(x='Order ID', 
				y='Carrier_y', data=minimum_cost_rows)
# Out:
# <Axes: xlabel='Order ID', ylabel='Carrier_y'>

# %%
sns.scatterplot(x='Order ID', 
				y='Port', data=minimum_cost_rows)
# Out:
# <Axes: xlabel='Order ID', ylabel='Port'>

# %%
sns.scatterplot(x='Order ID', 
				y='Total Cost', data=minimum_cost_rows)
# Out:
# <Axes: xlabel='Order ID', ylabel='Total Cost'>

# %%
sns.scatterplot(x='Total Cost', 
				y='Carrier_y', data=minimum_cost_rows)
# Out:
# <Axes: xlabel='Total Cost', ylabel='Carrier_y'>

# %%
sns.scatterplot(x='Carrier_y', 
				y='Port', data=minimum_cost_rows) 

#the carrier could also be 2, 3, 9?
# Out:
# <Axes: xlabel='Carrier_y', ylabel='Port'>
